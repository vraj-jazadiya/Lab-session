# %% [markdown]
# Set 2

# %%
#Q1.

import pandas as pd

series = pd.Series([300,1200,1700,100])

result = series[series > 200]
print(result)
# Out:
# 0     300
# 1    1200
# 2    1700
# dtype: int64

# %%
#Q2.

# %%
import pandas as pd

dic = {
    "filght_company_name" : ["indigo","air india","spaceX","indian airway","indigo","air india","spaceX","indian airway"],
    "source_city" : ["surat", "vadodara", "ahmdabad", "bharuch", "rajkot", "bhavangar","delhi", "mumbai"],
    "destination_city" : ["vadodara", "surat", "bharuch", "ahmdabad", "bhavangar", "rajkot","mumbai", "delhi"],
    "source_arrival_time" : [8, 9, 10, 15, 14, 13, 12, 11],
    "estination_arrival_time" : [18, 19, 20, 21, 22, 17, 18, 19],    
}

df = pd.DataFrame(dic)
print(df)

print("-------------------------------------------------------------------------------")
print(df[(df["estination_arrival_time"] >= 18) & (df["estination_arrival_time"] <= 20)])
# Out:
#   filght_company_name source_city destination_city  source_arrival_time  \
# 0              indigo       surat         vadodara                    8
# 1           air india    vadodara            surat                    9
# 2              spaceX    ahmdabad          bharuch                   10
# 3       indian airway     bharuch         ahmdabad                   15
# 4              indigo      rajkot        bhavangar                   14
# 5           air india   bhavangar           rajkot                   13
# 6              spaceX       delhi           mumbai                   12
# 7       indian airway      mumbai            delhi                   11
#
#    estination_arrival_time
# 0                       18
# 1                       19
# 2                       20
# 3                       21
# 4                       22
# 5                       17
# 6                       18
# 7                       19
# ...

# %%
#q3.

import numpy as np

arr = np.arra([10,20,30,40,50])

maxVl = np.max(arr)

print(arr)
print(maxVl)
# Out:
# [10 20 30 40 50 60 70]
# 70

# %%
#q4.

import pandas as pd
import matplotlib.pyplot as ply

df = pd.read_csv("../Medal.csv")

plt.bar(df["country"] ,df["gold_medal"] , color="red" , alpha=0.8)

for i in range(len(df)):
    plt.text(i,df['gold_medal'][i] ,df['gold_medal'][i])
    
plt.xlabel("X - Country")
plt.ylabel("Y - Gold medals")

plt.title("Gold medals of Country")
plt.show()

# %%
help(plt.text)
# Out:
# Help on function text in module matplotlib.pyplot:
#
# text(x: 'float', y: 'float', s: 'str', fontdict: 'dict[str, Any] | None' = None, **kwargs) -> 'Text'
#     Add text to the Axes.
#
#     Add the text *s* to the Axes at location *x*, *y* in data coordinates,
#     with a default ``horizontalalignment`` on the ``left`` and
#     ``verticalalignment`` at the ``baseline``. See
#     :doc:`/gallery/text_labels_and_annotations/text_alignment`.
#
#     Parameters
#     ----------
#     x, y : float
#         The position to place the text. By default, this is in data
#         coordinates. The coordinate system can be changed using the
#         *transform* parameter.
#
#     s : str
#         The text.
#
#     fontdict : dict, default: None
#
#         .. admonition:: Discouraged
#
#            The use of *fontdict* is discouraged. Parameters should be passed as
#            individual keyword arguments or using dictionary-unpacking
#            ``text(..., **fontdict)``.
#
# ...
